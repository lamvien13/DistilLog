# %%
# %cd /content/drive/MyDrive/colab/test/datasets/Thunderbird
# Out:
# /content/drive/MyDrive/colab/test/datasets/Thunderbird

# %%
import pandas as pd

df = pd.read_csv('Thunderbird_fulllog.csv')
full_log = df.values

split = int(0.7 * len(full_log))

train = full_log[:split]
test = full_log[split:]

print(len(full_log))
print(len(train)+len(test))
# Out:
# 199183
# 199183

# %%
train = pd.DataFrame(train)
train.to_csv('new_train.csv', index=False, header=False)

# %%
test = pd.DataFrame(test)
test.to_csv('new_test.csv', index = False, header = False)
